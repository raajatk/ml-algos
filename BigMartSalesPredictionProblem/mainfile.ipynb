# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('Train.csv')

# %%
dataframe.shape
# Out:
# (8523, 12)

# %%
dataframe.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
x_train = dataframe.drop(['Item_Outlet_Sales'],axis=1)

# %%
y_train = dataframe.drop(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
       'Item_Type', 'Item_MRP', 'Outlet_Identifier',
       'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
       'Outlet_Type'],axis=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# x_train = x_train.fillna(x_train['Item_Weight'].value_counts().index[0])
print(x_train.isnull().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 732.5+ KB

# %%
import copy

# %%
x_train_cat = x_train.select_dtypes(include=['object']).copy()

# %%
x_train_cat.head
# Out:
# <bound method NDFrame.head of      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# 5              FDP36          Regular           Baking Goods
# 6              FDO10          Regular            Snack Foods
# 7              FDP10          Low Fat            Snack Foods
# 8              FDH17          Regular           Frozen Foods
# 9              FDU28          Regular           Frozen Foods
# 10             FDY07          Low Fat  Fruits and Vegetables
# 11             FDA03          Regular                  Dairy
# 12             FDX32          Regular  Fruits and Vegetables
# 13             FDS46          Regular            Snack Foods
# ...

# %%
x_train_cat.isnull().sum()
# Out:
# Item_Identifier            0
# Item_Fat_Content           0
# Item_Type                  0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Outlet_Type                0
# dtype: int64

# %%
x_train_cat=x_train_cat.fillna(x_train_cat['Outlet_Size'].value_counts().index[0])

# %%
x_train_cat.isnull().sum()
# Out:
# Item_Identifier         0
# Item_Fat_Content        0
# Item_Type               0
# Outlet_Identifier       0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# dtype: int64

# %%
print(x_train_cat['Outlet_Type'].value_counts().count())
print(x_train_cat['Item_Identifier'].value_counts().count())
print(x_train_cat['Item_Fat_Content'].value_counts().count())
# Out:
# 4
# 1559
# 5

# %%
labels = x_train_cat['Item_Identifier'].astype('category').cat.categories.tolist()
replace_map_comp = {'Item_Identifier' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)
x_train_cat
# Out:
#       Item_Identifier Item_Fat_Content              Item_Type  \
# 0                 157          Low Fat                  Dairy
# 1                   9          Regular            Soft Drinks
# 2                 663          Low Fat                   Meat
# 3                1122          Regular  Fruits and Vegetables
# 4                1298          Low Fat              Household
# 5                 759          Regular           Baking Goods
# 6                 697          Regular            Snack Foods
# 7                 739          Low Fat            Snack Foods
# 8                 441          Regular           Frozen Foods
# 9                 991          Regular           Frozen Foods
# 10               1172          Low Fat  Fruits and Vegetables
# 11                148          Regular                  Dairy
# 12               1143          Regular  Fruits and Vegetables
# 13                905          Regular            Snack Foods
# ...

# %%
x_train_cat.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
labels = x_train_cat['Item_Fat_Content'].astype('category').cat.categories.tolist()
replace_map_comp = {'Item_Fat_Content' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)
x_train_cat
# Out:
#       Item_Identifier  Item_Fat_Content              Item_Type  \
# 0                 157                 2                  Dairy
# 1                   9                 3            Soft Drinks
# 2                 663                 2                   Meat
# 3                1122                 3  Fruits and Vegetables
# 4                1298                 2              Household
# 5                 759                 3           Baking Goods
# 6                 697                 3            Snack Foods
# 7                 739                 2            Snack Foods
# 8                 441                 3           Frozen Foods
# 9                 991                 3           Frozen Foods
# 10               1172                 2  Fruits and Vegetables
# 11                148                 3                  Dairy
# 12               1143                 3  Fruits and Vegetables
# 13                905                 3            Snack Foods
# ...

# %%
x_train_cat.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
labels = x_train_cat['Item_Type'].astype('category').cat.categories.tolist()
replace_map_comp = {'Item_Type' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)

# %%
labels = x_train_cat['Outlet_Identifier'].astype('category').cat.categories.tolist()
replace_map_comp = {'Outlet_Identifier' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)

# %%
labels = x_train_cat['Outlet_Size'].astype('category').cat.categories.tolist()
replace_map_comp = {'Outlet_Size' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)

# %%
labels = x_train_cat['Outlet_Location_Type'].astype('category').cat.categories.tolist()
replace_map_comp = {'Outlet_Location_Type' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)

# %%
labels = x_train_cat['Outlet_Type'].astype('category').cat.categories.tolist()
replace_map_comp = {'Outlet_Type' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# print(replace_map_comp)
x_train_cat.replace(replace_map_comp,inplace=True)

# %%
x_train_cat
# Out:
#       Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0                 157                 2          5                 10
# 1                   9                 3         15                  4
# 2                 663                 2         11                 10
# 3                1122                 3          7                  1
# 4                1298                 2         10                  2
# 5                 759                 3          1                  4
# 6                 697                 3         14                  2
# 7                 739                 2         14                  6
# 8                 441                 3          6                  8
# 9                 991                 3          6                  3
# 10               1172                 2          7                 10
# 11                148                 3          5                  9
# ...

# %%
print(x_train['Item_Identifier'][0])
x_train_cat['Item_Identifier'][0]
# Out:
# FDA15
# 157

# %%
x_train_cat.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
x_train['Item_Identifier'] = x_train_cat['Item_Identifier']
x_train['Item_Fat_Content'] = x_train_cat['Item_Fat_Content']
x_train['Item_Type'] = x_train_cat['Item_Type']
x_train['Outlet_Identifier'] = x_train_cat['Outlet_Identifier']
x_train['Outlet_Size'] = x_train_cat['Outlet_Size']
x_train['Outlet_Location_Type'] = x_train_cat['Outlet_Location_Type']
x_train['Outlet_Type'] = x_train_cat['Outlet_Type']

# %%
x_train
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 157        9.300                 2         0.016047
# 1                   9        5.920                 3         0.019278
# 2                 663       17.500                 2         0.016760
# 3                1122       19.200                 3         0.000000
# 4                1298        8.930                 2         0.000000
# 5                 759       10.395                 3         0.000000
# 6                 697       13.650                 3         0.012741
# 7                 739          NaN                 2         0.127470
# 8                 441       16.200                 3         0.016687
# 9                 991       19.200                 3         0.094450
# 10               1172       11.800                 2         0.000000
# 11                148       18.500                 3         0.045464
# ...

# %%
x_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
x_train=x_train.fillna(x_train['Item_Weight'].value_counts().index[0])

# %%
x_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
x_train.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
x_train
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 157        9.300                 2         0.016047
# 1                   9        5.920                 3         0.019278
# 2                 663       17.500                 2         0.016760
# 3                1122       19.200                 3         0.000000
# 4                1298        8.930                 2         0.000000
# 5                 759       10.395                 3         0.000000
# 6                 697       13.650                 3         0.012741
# 7                 739       12.150                 2         0.127470
# 8                 441       16.200                 3         0.016687
# 9                 991       19.200                 3         0.094450
# 10               1172       11.800                 2         0.000000
# 11                148       18.500                 3         0.045464
# ...

# %%
y_train
# Out:
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# 5              556.6088
# 6              343.5528
# 7             4022.7636
# 8             1076.5986
# 9             4710.5350
# 10            1516.0266
# 11            2187.1530
# 12            1589.2646
# 13            2145.2076
# 14            1977.4260
# 15            1547.3192
# 16            1621.8888
# 17             718.3982
# 18            2303.6680
# 19            2748.4224
# 20            3775.0860
# 21            4064.0432
# 22            1587.2672
# 23             214.3876
# 24            4078.0250
# 25             838.9080
# 26            1065.2800
# 27             308.9312
# 28             178.4344
# 29             125.8362
# ...                 ...
# 8493          4727.1800
# 8494          1637.8680
# 8495          4314.3840
# 8496          3715.1640
# 8497          2247.0750
# 8498          1601.2490
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x_train,y_train,test_size=0.2, random_state=0)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Y_pred = model.predict(X_test)

# %%
model.score(X_test,Y_test)
# Out:
# 0.5127950434315045

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

lin2 = LinearRegression()
lin2.fit(X_train_poly,Y_train)

Y_pred2 = lin2.predict(X_test_poly)
lin2.score(X_test_poly,Y_test)
# Out:
# 0.5523026356831069
